# %% [markdown]
# ### Study Outline for Statistics Assessment

# %% [markdown]
# ![Screen%20Shot%202021-02-12%20at%206.38.12%20PM.png](attachment:Screen%20Shot%202021-02-12%20at%206.38.12%20PM.png)

# %% [markdown]
# Type I Error: (FALSE Positive - false alarm)
# * Observe differences when none exist
# * Boy cries wolf and town reacts, but there isn't one
#
# Type II Error: (FALSE Negative - no alarm)
# * Fail to observe difference when on exists
# * Town doesn't react, but there is a wolf
